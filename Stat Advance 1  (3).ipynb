# %% [markdown]
# Q.1 What is a random variable in probability theory?
# ANS: A random variable is a mathematical function that assigns a numerical value to each outcome of a random experiment.
#
#
# Q.2  What are the types of random variables?
# ANS: There are three principal types:
#
# 1. Discrete Random Variable
# Takes on a countable number of distinct values (e.g. integers): like the number of heads in coin tosses or the number of emails received per day.
# Probability described by a probability mass function (PMF), where the probabilities sum to 1.
# Examples include Bernoulli, Binomial, Geometric, and Poisson random variables
#
# 2. Continuous Random Variable
# Takes values from an uncountably infinite continuum, e.g. heights, times, weight.
# Each specific value has probability zero; probabilities are associated with intervals and described by a probability density function (PDF)
#
# 3. Mixed Random Variable
# Combines both discrete and continuous features: for instance, a variable with a positive probability at a specific point along with a continuous spread elsewhere.
# Examples include waiting time at a traffic light (zero wait with some probability, otherwise positive continuous wait) or experiments combining a coin toss and spinner
#
#
#
#  Q.3  What is the difference between discrete and continuous distributions?
#  ANS: Here’s how discrete and continuous probability distributions differ:
#
# 1. Nature of Outcomes
# Discrete distributions model countable outcomes—either finite or countably infinite. Examples include the roll of a die, number of children, or daily emails received.
# Continuous distributions describe uncountably infinite outcomes, such as heights, weights, or exact measurement values on a continuous interval.
#
# 2. Probability Assignment
# In a discrete distribution, each individual outcome x.
# x has a nonzero probability, given by the probability mass function (PMF). The probabilities over all possible values sum to 1.
# In a continuous distribution, the probability of the variable taking any specific exact value is zero. Instead, probability is assigned over intervals using the probability density function (PDF).
#
# 3. Mathematical Representation
# Discrete: Probability is calculated via sums of PMF values. For instance,
# P(X=k)=f(k).
# Individual point probabilities vanish.
#
#
# 4. Cumulative Distribution Function (CDF)
# Discrete: The CDF is a step function, jumping at each possible value.
# Continuous: The CDF is a smooth, continuous curve. If absolutely continuous, its derivative exists almost everywhere and equals the PDF.
#
# 5. Examples & Use Cases
# Discrete:
#
# Binomial (number of successes in independent trials)
# Poisson (count of events in a time or space interval)
#
#
# Continuous:
#
# Normal distribution (e.g. heights, IQ scores)
# Exponential, Uniform over intervals
#
#
# 6. Practical Implications
# If you're modeling counts—something you can list or enumerate—use a discrete distribution.
# If you're modeling measurements—things like time, length, or temperature—use a continuous distribution.
# Choose between discrete and continuous based on the type of data, not always how it's recorded—for example, age in years (although discrete in recorded form) is often treated as continuous in analysis.
#
#
#
# Q.4 What are probability distribution functions (PDF)?
# ANS:  When we talk about probability distribution functions (PDF) in probability theory, the term can refer to a few related but distinct concepts depending on whether the variable is discrete or continuous.
#
# Probability Mass Function (PMF) — for discrete random variables
# For discrete random variables, which take countable values (like integers), the PDF often refers to the probability mass function (PMF).
# P(X=k)=p(k),and probabilities across all possible values sum to 1
#
#
# Probability Density Function (pdf) — for continuous random variables
# For continuous random variables (values lie on real intervals), the PDF refers to the probability density function, denoted
# P(X=x)=0 for any single
# f(x)dx
# The PDF must satisfy:
# f(x)dx=1 (total probability equals unity)
#
#
# Q.5  How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# ANS:  Here’s a clearer breakdown of how cumulative distribution functions (CDFs) differ from probability distribution functions (PDFs):
# What They Represent
# A PDF, in the context of continuous variables, is a probability density function. It indicates how densely probability is distributed near each value—not the actual probability of hitting exactly that value, which is always zero for continuous variables. You interpret probability via the area under the PDF curve over an interval.
#
# A CDF, or cumulative distribution function, gives the probability that a random variable
# X is less than or equal to a given value
# F(x)=P(X≤x)
#
#
# Q.6 What is a discrete uniform distribution?
# ANS:  A discrete uniform distribution models a scenario where a random variable takes on a finite set of distinct integer values, each with exactly the same probability.
#  Definition & Key Properties
# If X is uniformly distributed over the integer set
# {a,a+1,…,b}, then:
# for every integer
# P(X=k)=
# b−a+1
#
# for every integer k∈ [a, b]
# n=b−a+1, so each outcome’s probability is 1/n
#
# Examples
# Rolling a fair six‑sided die.
# Drawing a card suit from a standard deck, interpreted as integers 1–4 for suits. Each suit has probability.
# Selecting a random integer between 1 and 10: each integer has probability .
#
#
#
# Q.7  What are the key properties of a Bernoulli distribution?
# ANS:  Here are the key properties of the Bernoulli distribution, a simple but fundamental discrete distribution:
#
# Definition (PMF)
# A Bernoulli-distributed random variable
# X∼Bernoulli(p) takes only two values:
#
# P(X=1)=p (success)
# P(X=0)=1−p=q (failure)
#
# This can also be written compactly as:
# P(X=x)=p x (1−p) 1−x ,x∈{0,1}
#
#  Mean and Variance
# Expected value (mean):
# E[X]=p
# This reflects the long-run proportion of successes.
#
# Variance:
# Var(X)=p(1−p)=pq
# Notice the uniform spread is highest when p=0.5, and goes to zero as 𝑝
# p approaches 0 or 1.
# Because
#
# Var(X)=E[X]−(E[X])
# 2 =p−p
# 2 =p(1−p)
#
# Skewness, Kurtosis & Mode
# Skewness:
# p(1−p) 1−2p
# Skew is zero at
# 𝑝= 0.5
# p=0.5; positive for
# 𝑝<0.5
# p<0.5, negative for
# 𝑝>0.5
#
# Excess Kurtosis:
# p(1−p)6p 2−6p+1
#
# Diverges as
# p→0 or 1 , minimal at 𝑝=0.5
#
# Mode (most probable value):
# Mode = 1 if 𝑝>0.5p>0.5
# Mode = 0 if
# 𝑝<0.5
# Both 0 and 1 if
# 𝑝=0.5
#
#
#
#
# Q.8 What is the binomial distribution, and how is it used in probability?
# ANS: Here’s a detailed overview of the binomial distribution, how it's defined, and how it's applied in probability and real-world scenarios:
# Definition
# A binomial distribution models the probability of observing exactly  k successes in n independent Bernoulli trials, each with the same probability 𝑝
# p of success ⁠— where each trial has just two outcomes: success or failure.
# Examples & Applications:
# Flipping a coin
# n=10,
# p=0.5.
#
# Probability of exactly 3 heads:
#
# P(X=3)=( 10/3) ≈0.1172
#
#
# Q.9 What is the Poisson distribution and where is it applied?
# ANS: Here's a concise and clear overview of the Poisson distribution and its real-world utility:
# What Is the Poisson Distribution?
# It is a discrete probability distribution describing the probability of observing exactly k events in a fixed interval of time or space, given a known average rate λ.
#
# It assumes events:
# Occur independently,
# At a constant average rate,
# And rarely enough that multiple events in an infinitesimally small interval are negligible.
#
#  Key Properties
# Mean and variance are equal:
# E[X]=λ,Var(X)=λ
# Suitable for rare events in a fixed window, not counts of successes among fixed trials (unlike binomial).
#
# Real-World Applications
# The Poisson distribution is widely applied in various fields:
# Queueing Theory & Telecommunications
# Modeling customer or call arrivals at service centers to plan staffing and resources
# Traffic & Accident Analysis
# Counting vehicles or accidents in a specified time or road section—for road design, safety planning, and incident prediction
# Healthcare & Epidemiology
# Estimating rare disease incidences or ER visits in a time frame for resource allocation and outbreak detection
# Insurance & Risk Management
# Modeling claim counts, mortality events, or reinsurance needs in actuarial calculations
#
#
#
# Q.10 What is a continuous uniform distribution?
# ANS:  continuous uniform distribution (also known as the rectangular distribution) is a probability distribution where all values within a continuous interval [a,b] are equally likely.
#
#
# Q.11  What are the characteristics of a normal distribution?
# ANS: Symmetry
# The normal distribution is perfectly symmetric about its mean. This means the left and right halves of the distribution are mirror images of each other. Consequently, the mean, median, and mode of the distribution are all equal and located at the center.
#
# Bell-Shaped Curve
# The probability density function (PDF) of a normal distribution forms a bell-shaped curve, with the highest point at the mean. The curve tapers off symmetrically as it moves away from the mean, approaching but never touching the horizontal axis.
#
# Empirical Rule (68-95-99.7 Rule)
# For a normal distribution:
# Approximately 68% of the data falls within one standard deviation of the mean.
# Approximately 95% falls within two standard deviations.
# Approximately 99.7% falls within three standard deviations.
# This rule helps in understanding the spread and variability of data.
#
# Asymptotic Nature
# The tails of the normal distribution curve extend infinitely in both directions. Although they approach the horizontal axis, they never actually touch it, indicating that extreme values, while rare, are always possible.
#
# Defined by Two Parameters
# A normal distribution is fully characterized by its mean (μ) and standard deviation (σ):
# Mean (μ): Determines the center of the distribution.
# Standard Deviation (σ): Measures the spread or dispersion of the data.
# These parameters dictate the shape and position of the distribution curve.
#
# Skewness and Kurtosis
# Skewness: The normal distribution has a skewness of 0, indicating no asymmetry.
# Kurtosis: The normal distribution has a kurtosis of 3, which is considered mesokurtic, meaning it has a moderate peak and tails.
#
#
#
# Q.12 What is the standard normal distribution, and why is it important ?
# ANS: The standard normal distribution is a special case of the normal distribution. It is a continuous probability distribution with the following characteristics:
#
# Mean (μ): 0
# Standard Deviation (σ): 1
# Skewness: 0 (symmetrical)
# Kurtosis: 3 (mesokurtic)
# Shape: Bell-shaped curve centered at 0
#
# This distribution is often referred to as the Z-distribution because its values are expressed in terms of Z-scores, which represent the number of standard deviations a data point is from the mean.
#
# Importance of the Standard Normal Distribution
# Standardization of Data
# By converting data from any normal distribution to the standard normal distribution, we can compare data points from different datasets on a common scale. This process, known as standardization, involves calculating the Z-score for each data point:
# The standard normal distribution simplifies the calculation of probabilities. Standard normal tables (Z-tables) provide the cumulative probability associated with Z-scores, enabling quick determination of the likelihood of a data point occurring within a certain range.
#
# Foundation for Statistical Inference
# Many statistical tests, such as the Z-test, rely on the assumption that data follows a standard normal distribution. This assumption allows for the derivation of critical values and p-values, which are essential for hypothesis testing and confidence interval estimation.
#
# Central Limit Theorem (CLT)
# The CLT states that the distribution of the sample mean approaches a standard normal distribution as the sample size increases, regardless of the original distribution of the data. This principle underpins many statistical methods and justifies the use of the standard normal distribution in inferential statistics.
#
# Applications in Quality Control and Machine Learning
# In quality control, the standard normal distribution is used to monitor product quality and detect anomalies. In machine learning, algorithms often assume that data is normally distributed, and standardization ensures that features contribute equally to model performance.
#
#
#
# Q.13  What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# ANS: The Central Limit Theorem (CLT) is a fundamental concept in statistics that explains why many statistical methods work effectively, even when the underlying data distribution is unknown.
# The CLT states that if you take sufficiently large random samples from any population with a finite mean and variance, the distribution of the sample means will approach a normal distribution (bell curve), regardless of the original population's distribution.
# This normal distribution will have:
# Mean (μ) equal to the population mean.
# Standard deviation (σ/√n), where n is the sample size.
# A common rule of thumb is that a sample size of 30 or more is typically sufficient for the CLT to hold.
#
#  Why Is the CLT Critical in Statistics?
# Foundation for Inferential Statistics
# The CLT justifies the use of the normal distribution in statistical inference, enabling the creation of confidence intervals and hypothesis tests.
# Simplifies Complex Problems
# It allows statisticians to make inferences about population parameters even when the population distribution is unknown.
# Enables Reliable Sampling
# The CLT ensures that sample means are reliable estimators of the population mean, making sampling a powerful tool for data analysis.
# Supports Statistical Tests
# Many statistical tests, such as t-tests and z-tests, rely on the assumption that sample means follow a normal distribution, which is guaranteed by the CLT for large sample sizes.
#
#
# Q.14  How does the Central Limit Theorem relate to the normal distribution?
# ANS: The Central Limit Theorem (CLT) is a fundamental concept in statistics that explains how the distribution of sample means approaches a normal distribution, regardless of the population's original distribution, as the sample size increases.
#
# CLT and Normal Distribution: The Connection
# The CLT asserts that when you take sufficiently large random samples from any population with a finite mean and variance, the distribution of the sample means will approximate a normal distribution. This holds true even if the original population distribution is not normal. As the sample size grows, the sample means converge to a normal distribution with:
#
# Mean (μ): Equal to the population mean.
# Standard Deviation (σ/√n): Where n is the sample size.
#
# This convergence allows statisticians to apply normal distribution-based methods, such as confidence intervals and hypothesis tests, even when the underlying data distribution is unknown.
#
#
#
# Q.15 What is the application of Z statistics in hypothesis testing?
# ANS: The Z-test is a statistical method used in hypothesis testing to determine if there is a significant difference between a sample mean and a population mean, or between two sample means. It is particularly useful when the sample size is large (typically n > 30) and the population standard deviation is known.
# Applications of Z-Tests
# Quality Control: Monitoring manufacturing processes to ensure products meet specifications.
# Finance: Evaluating investment returns against benchmarks.
# Healthcare: Assessing the effectiveness of treatments or interventions.
# Education: Comparing student performance across different schools or districts.
#
#
# Q.16  How do you calculate a Z-score, and what does it represent?
# ANS: A Z-score, also known as a standard score or z-value, quantifies how many standard deviations a data point (raw score) is from the mean of its dataset. It standardizes data, enabling comparisons across different distributions or scales.
# Wikipedia
#
# How to Calculate a Z-Score
# The formula for calculating a Z-score is:
# Z= σx−μ
# Where:
# x = raw score (individual data point)
# μ = population mean
# σ = population standard deviation
#
# If the population mean (μ) and standard deviation (σ) are unknown, you can use the sample mean (x ) and sample standard deviation (s) to estimate the Z-score.
# This adjustment is common when working with sample data.
#
#
#
# Q.17  What are point estimates and interval estimates in statistics?
# ANS:
# 1. Point Estimates
# A point estimate is a single best-guess value drawn from your sample data to approximate a population parameter.
#
# Example: x  estimates the population mean μ, and p estimates the population proportion
#
# It’s straightforward and easy to interpret, but it does not reflect any uncertainty. It’s rarely exactly correct.
#
# Sample Terminology:
# A point estimator is a statistic (like the sample mean).
# A point estimate is the numerical value obtained from your sample.
# “x̄ is an estimator. x̄ = 4.5 is a point estimate given a dataset.”
#
# 2. Interval Estimates (Confidence Intervals)
# An interval estimate offers a range of plausible values for the unobserved population parameter, along with a confidence level (e.g., 95%).
# A confidence interval (CI) is constructed as:Point Estimate ±(Critical Value)×(Standard Error)
# Point Estimate±(Critical Value)×(Standard Error)
#
#
#
#
# Q.18 What is the significance of confidence intervals in statistical analysis?
# ANS:
# 1. Quantifies Precision & Uncertainty
# CIs show how precise your estimate is: a narrower interval means higher precision, wider means more uncertainty. Rather than a single number, you see a plausible range for the true value
#
# 2. Communicates Effect Sizes & Relevance
# Unlike p-values, CIs present effect sizes in real units and help assess clinical or practical importance. Even statistically significant results can be clinically unimportant if the CI spans negligible values
#
# 3. Dual with Hypothesis Testing
# A 95% CI that excludes the null value (e.g. zero for mean difference, one for risk ratio) corresponds to rejecting the null at α = 0.05. Conversely, if the null lies within the interval, the result is not statistically significant at that level
#
# 4. Guides Decision-Making & Study Design
# CIs assist in sample size planning—selecting the number needed to achieve desired precision—and support decision-making in fields like medicine, quality control, and marketing
#
# 5. Improves Transparency and Reproducibility
# By reporting both point estimates and CIs, researchers allow others to evaluate the strength, direction, and reliability of the findings in context—not just whether they reach statistical significance
#
#
#
#
# Q.19 What is the relationship between a Z-score and a confidence interval?
# ANS: The Z-score plays a central role in constructing confidence intervals (CIs) and directly links to how we interpret confidence levels in statistical inference. Here's how they connect:
#
# 1. Z-score Defines the Margin of Error in a CI
# When you know the population standard deviation (σ) and have a sufficiently large sample (n≥30), the confidence interval for a population mean (μ) is given by:
#
# CI= xˉ ±Z ∗ ( n/σ )
# x = sample mean
# σ/ n = standard error
# Z   = Z-score (critical value) chosen to match your desired confidence level (e.g. 1.96 for 95%)
# So the Z-score directly determines how wide your interval is—the margin of error increases in proportion to
#
#
# 2. How the Z-score Is Derived from Confidence Level To choose 𝑍  for a particular confidence level 𝐶
# Common critical Z-values:
# 90% → 1.645
# 95% → 1.96
# 99% → 2.576
#
#
# 3. Higher Confidence → Larger Z-score → Wider Interval
# There’s a trade-off:
# Higher confidence (e.g. 99%) yields a larger Z-score, giving a wider interval, so there's more certainty but less precision.
# Lower confidence (e.g. 90%) uses a smaller Z-score, yielding a narrower interval, more precise but less confident
#
#
# 4. Relationship with Standardized Distance (Z-score)
# The Z-score also expresses how far x  is from μ, in standard error units:
# This formulation means that once x  is standardized, the sampling distribution of the mean is approximately standard normal (by the CLT), allowing us to use Z-scores for CI construction
#
#
#
#
#
# Q.20 How are Z-scores used to compare different distributions?
# ANS:
# Standardization Across Scales Z‑scores remove differences in units and spread, allowing you to compare apples to oranges—literally and figuratively. A Z‑score of +2 in one distribution and +3 in another immediately shows that the latter value is more exceptional in its context.
#
# Relative Position Within Distributions
# A higher absolute Z‑score value denotes a data point farther from its mean, regardless of the distribution’s original scale.
#
# Probability & Extremeness Interpretation
# When the data is normal (or approximately so), Z‑scores align with the empirical rule:
# ~68% of values fall between Z = –1 and +1,
# ~95% between –2 and +2,
# ~99.7% between –3 and +3.
# Thus, Z-scores help assess how rare or extreme a value is.
#
# In short, Z‑scores let you standardize and compare data points across disparate scales and distributions by placing each observation on a shared reference frame. This makes interpreting relative performance, extremeness, and probabilities straightforward—even when data comes from very different sources.
#
#
#
#
# Q.21  What are the assumptions for applying the Central Limit Theorem?
# ANS:  Here are the key assumptions required for the Central Limit Theorem (CLT) to hold—and why they matter in statistical inference:
#
# Independence of observations
#
# Each sampled value should not influence others.
#
# If sampling without replacement, the sample size should be ≤ 10% of the population to maintain approximate independence
#
#
# Identically distributed (i.i.d.) variables
#
# Observations must come from the same underlying distribution with constant mean and variance
#
#
# Finite variance and mean
#
# The source distribution must have well-defined, finite variance (e.g. excludes heavy-tailed distributions like Cauchy)
#
#
# Sufficiently large sample size
# Typically n≥30 is used as a rule of thumb for many distributions.
# For highly skewed or heavy-tailed populations, much larger n may be needed to achieve approximate normality
#
#
#
# Q.22  What is the concept of expected value in a probability distribution?
# ANS:  The expected value—often denoted as E[X] or μ—is a fundamental concept in probability and statistics. It represents the long-term average or central location of a random variable’s distribution. Here's a detailed breakdown of what it means and why it's important:
# Expected value is like asking: “If I repeated this random process many times, what average value would I expect over the long run?”
# For example:
# Rolling a fair 6‑sided die: each face has probability 1/6, so the expected roll is
# 1+2+3+4+5+6 / 6 =3.5 even though you can never roll a 3.5 in a single throw
#
# Coin flips (Bernoulli trials): If X=1 with probability p and 0 otherwise, then E[X]=p (interpreted as the expected proportion of successes)
#
#
#
# Q.23 How does a probability distribution relate to the expected outcome of a random variable?
# ANS: A probability distribution defines all possible outcomes of a random variable and assigns probabilities to each outcome (or to intervals, in the continuous case) . The expected value, or expected outcome, is the probability-weighted average of those outcomes. It captures the long-run average result you would observe if you repeated the random process many times
#
# Discrete Case
# Each possible outcome contributes in proportion to how likely it is. For instance, rolling a fair six‑sided die:
# Even though you can’t roll a 3.5, it represents the average over many rolls
#
# Continuous Case
# It generalizes the discrete sum to an integral for continuous distributions.

# %%
Q.1 Write a Python program to generate a random variable and display its value.
ANS: import random

# Generate a random integer between 1 and 10 (inclusive)
random_integer = random.randint(1, 10)
print("Random Integer:", random_integer)

# Generate a random floating-point number between 0.0 and 1.0
random_float = random.random()
print("Random Float [0.0, 1.0):", random_float)

# Generate a random float in a specific range, e.g., between 5.0 and 15.0
random_uniform = random.uniform(5.0, 15.0)
print("Random Float [5.0, 15.0):", random_uniform)


Here’s what each function does:

random.randint(a, b) returns a random integer between a and b, inclusive 

random.random() generates a random floating‑point number in the interval [0.0, 1.0) 

random.uniform(a, b) returns a random float between a and b, where a may be included and b is typically excluded  




Q.2   Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the discrete uniform distribution parameters (like a fair six‑sided die)
a, b = 1, 6
dist = randint(low=a, high=b + 1)

# Define possible outcome values
values = np.arange(a, b + 1)

# Theoretical PMF values for each outcome
pmf_vals = dist.pmf(values)  # Equal probabilities of 1/(b-a+1)
# Empirical data: sample many random variates
samples = dist.rvs(size=1000)

# Plot both the empirical distribution (normalized histogram) and theoretical PMF
fig, ax = plt.subplots(figsize=(8, 5))
# Histogram approximates the PMF
ax.hist(samples, bins=np.arange(a, b + 2) - 0.5, density=True,
        alpha=0.6, color='gray', label='Empirical (histogram)')
# Theoretical PMF as points and vertical lines
ax.scatter(values, pmf_vals, color='red', zorder=5, label='Theoretical PMF')
ax.vlines(values, 0, pmf_vals, color='red', linestyles='--', zorder=4)

# Labels and appearance
ax.set_xticks(values)
ax.set_xlabel('Value')
ax.set_ylabel('Probability')
ax.set_title(f'Discrete Uniform Distribution PMF (from {a} to {b})')
ax.set_ylim(0, max(pmf_vals)*1.2)
ax.legend()
plt.show()






Q.3  Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution
ANS: def bernoulli_pmf(k, p):
    """
    Compute the probability mass function of a Bernoulli distribution.

    Parameters:
    - k: int (must be 0 or 1)
    - p: float in [0, 1], probability of success (i.e., P(X=1))

    Returns:
    - Probability P(X = k)
    """
    if k == 0:
        return 1 - p
    elif k == 1:
        return p
    else:
        return 0.0  # probability zero for any other k






Q.4 Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram
ANS: 
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10
p = 0.5
size = 10000  # number of simulations

# Simulate binomial outcomes
data = np.random.binomial(n=n, p=p, size=size)

# Plot histogram (normalized to show probabilities)
plt.hist(data, bins=np.arange(-0.5, n+1.5, 1),
         density=True, edgecolor='black', alpha=0.7,
         label='Empirical histogram')

# Overlay theoretical PMF
x = np.arange(0, n+1)
pmf = binom.pmf(x, n=n, p=p)
plt.scatter(x, pmf, color='red', zorder=5, label='Theoretical PMF')
plt.vlines(x, 0, pmf, color='red', linestyle='dashed')

# Labels and styling
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(x)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()






Q.5   Create a Poisson distribution and visualize it using Python
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lam = 4  # average rate λ
size = 1000  # number of samples

# Simulate Poisson-distributed data
data = poisson.rvs(mu=lam, size=size)

# Plot histogram (normalized to show probabilities)
bins = np.arange(0, max(data) + 2) - 0.5
plt.hist(data, bins=bins, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Simulated data')

# Compute theoretical PMF
k = np.arange(0, max(data) + 1)
pmf = poisson.pmf(k, mu=lam)

# Overlay PMF
plt.vlines(k, 0, pmf, colors='red', linestyles='--', label='Theoretical PMF')
plt.scatter(k, pmf, color='red')

# Styling
plt.title(f'Poisson Distribution (λ={lam})')
plt.xlabel('Number of Events (k)')
plt.ylabel('Probability')
plt.xticks(k)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()







Q.6 Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
uniform distribution
ANS:  import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the discrete uniform distribution parameters
a, b = 1, 6  # e.g., a fair six-sided die (1 through 6)
dist = randint(low=a, high=b+1)

# Create an array of possible outcome values
values = np.arange(a, b+1)

# Compute the cumulative distribution function (CDF) at each value
cdf_vals = dist.cdf(values)

# Plot the CDF as a step function
plt.figure(figsize=(8, 5))
plt.step(values, cdf_vals, where='post', label='Discrete Uniform CDF', color='blue', marker='o')
plt.title(f'CDF of Discrete Uniform Distribution [{a}, {b}]')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.xticks(values)
plt.ylim(0, 1.05)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()




Q.7 Generate a continuous uniform distribution using NumPy and visualize it
ANS:  import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Distribution parameters
a, b = 2.0, 5.0  # interval [a, b)
size = 10000     # number of random samples

# Generate samples
data = np.random.uniform(low=a, high=b, size=size)  # NumPy method :contentReference[oaicite:2]{index=2}

# Plot histogram of samples
plt.figure(figsize=(8, 5))
count, bins, _ = plt.hist(data, bins=50, density=True, color='skyblue',
                          edgecolor='black', alpha=0.7,
                          label='Sampled data')

# Overlay theoretical PDF
x = np.linspace(a, b, 200)
pdf = uniform.pdf(x, loc=a, scale=b - a)
plt.plot(x, pdf, 'r-', lw=2, label='Theoretical PDF')  # using scipy.stats.uniform :contentReference[oaicite:3]{index=3}

# Labels and aesthetics
plt.title(f'Continuous Uniform Distribution U({a}, {b})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()




Q.8 Simulate data from a normal distribution and plot its histogram
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simulation parameters
mean = 0.0         # μ
std_dev = 1.0      # σ
size = 100_000     # number of samples

# Generate data
data = np.random.normal(loc=mean, scale=std_dev, size=size)
# Alternatively: data = norm.rvs(loc=mean, scale=std_dev, size=size)

# Plot histogram (normalized to form a PDF)
count, bins, _ = plt.hist(data, bins=50, density=True,
                          color='skyblue', alpha=0.6, edgecolor='black',
                          label='Simulated data')

# Compute theoretical PDF
x = np.linspace(bins.min(), bins.max(), 200)
pdf = norm.pdf(x, loc=mean, scale=std_dev)

# Overlay the PDF curve
plt.plot(x, pdf, color='red', lw=2, label='Theoretical PDF')

# Labels and styling
plt.title(f'Normal Distribution (μ={mean}, σ={std_dev})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()




Q.9  Write a Python function to calculate Z-scores from a dataset and plot them
ANS:  import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

def plot_z_scores(data, ddof=0):
    """
    Compute Z-scores for 'data' (1D array or list), plot histogram.

    Parameters:
      data : array-like
        Numeric data to standardize.
      ddof : int
        Degrees of freedom correction for standard deviation (default 0).
    """
    # Convert to NumPy array
    values = np.asarray(data)
    
    # Compute Z-scores using SciPy for robustness
    zs = zscore(values, ddof=ddof)  # mean and std internally handled :contentReference[oaicite:2]{index=2}

    # Plot the Z-score histogram
    plt.figure(figsize=(8, 5))
    plt.hist(zs, bins=30, density=True, alpha=0.7, color='skyblue', edgecolor='black')
    plt.title('Histogram of Z‑Scores')
    plt.xlabel('Z‑Score')
    plt.ylabel('Density')
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.show()
    
    return zs






Q.10   Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
ANS:  import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
np.random.seed(42)  # For reproducibility
population_size = 10000
sample_size = 30
num_samples = 1000

# Generate a population from an exponential distribution
population = np.random.exponential(scale=2.0, size=population_size)

# Collect sample means
sample_means = [np.mean(np.random.choice(population, size=sample_size)) for _ in range(num_samples)]

# Plot the population distribution
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(population, bins=50, density=True, alpha=0.6, color='g')
plt.title('Population Distribution (Exponential)')
plt.xlabel('Value')
plt.ylabel('Density')

# Plot the sampling distribution of the sample means
plt.subplot(1, 2, 2)
plt.hist(sample_means, bins=50, density=True, alpha=0.6, color='b')
plt.title('Sampling Distribution of Sample Means')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

# Overlay a normal distribution curve
mu, std = np.mean(sample_means), np.std(sample_means)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
plt.tight_layout()
plt.show()






Q.11 Simulate multiple samples from a normal distribution and verify the Central Limit Theorem
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def simulate_clt(population, sample_sizes, num_samples=1000, seed=42):
    np.random.seed(seed)
    results = {}
    for n in sample_sizes:
        sample_means = [ np.mean(np.random.choice(population, size=n, replace=True))
            for _ in range(num_samples)]
        results[n] = np.array(sample_means)
    return results

def plot_clt_results(population, results):
    fig, axes = plt.subplots(1, len(results) + 1, figsize=(5 * (len(results) + 1), 4))
    # Plot population
    ax = axes[0]
    ax.hist(population, bins=50, density=True, alpha=0.6, color='gray')
    ax.set_title("Population Distribution")
    ax.set_xlabel("Value")
    ax.set_ylabel("Density")

    # Plot each sampling distribution
    for idx, (n, means) in enumerate(results.items(), start=1):
        ax = axes[idx]
        ax.hist(means, bins=30, density=True, alpha=0.6, label="Sample means (n={})".format(n))
        mu, sigma = means.mean(), means.std()
        x = np.linspace(mu - 4*sigma, mu + 4*sigma, 200)
        ax.plot(x, norm.pdf(x, mu, sigma), 'r--', lw=2, label="Normal fit")
        ax.set_title(f"Sampling dist (n={n})")
        ax.set_xlabel("Mean value")
        ax.set_ylabel("Density")
        ax.legend()
    plt.tight_layout()
    plt.show()

# Example usage:
# Generate a skewed non-normal population: exponential distribution
population = np.random.exponential(scale=2.0, size=10000)



Q.12 Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal():
    """
    Plot the standard normal distribution PDF: mean=0, std=1.
    """
    mu = 0
    sigma = 1
    x = np.linspace(mu - 4*sigma, mu + 4*sigma, 500)
    y = norm.pdf(x, loc=mu, scale=sigma)

    plt.figure(figsize=(8, 5))
    plt.plot(x, y, label='Standard Normal PDF (μ=0, σ=1)')
    plt.fill_between(x, y, alpha=0.2)
    plt.title('Standard Normal Distribution')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.show()

    if __name__ == '__main__':
    plot_standard_normal()






Q.13 Generate random variables and calculate their corresponding probabilities using the binomial distribution
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

def simulate_and_compute_binomial(n, p, num_samples=1000):
    # Step 1: Generate binomial random variables (number of successes)
    samples = np.random.binomial(n=n, p=p, size=num_samples)
    
    # Step 2: Compute the theoretical PMF for all possible outcomes k = 0 to n
    k_values = np.arange(n + 1)
    pmf_values = binom.pmf(k_values, n, p)
    
    return samples, k_values, pmf_values

def plot_binomial_results(samples, k_values, pmf_values, n, p):
    plt.figure(figsize=(8, 5))
    
    # Empirical histogram of sample outcomes
    plt.hist(samples, bins=np.arange(n + 2) - 0.5, density=True,
             alpha=0.6, color='skyblue', edgecolor='black',
             label='Empirical frequencies')
    
    # Theoretical PMF overlay
    plt.scatter(k_values, pmf_values, color='red', zorder=5, label='Theoretical PMF')
    plt.vlines(k_values, 0, pmf_values, colors='red', linestyles='--', zorder=4)
    
    plt.title(f'Binomial Distribution (n={n}, p={p})')
    plt.xlabel('Number of Successes (k)')
    plt.ylabel('Probability')
    plt.xticks(k_values)
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# Example usage:
n = 10        # number of trials
p = 0.3       # probability of success on each trial
num_samples = 10000






Q.14 Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
distribution
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def z_score_probability(x, data, plot=True):
    
    Calculate Z-score for a data point and its corresponding standard normal probabilities.
    
    Parameters:
        x (float): data point
        data (array-like): list or array of observations (to compute mean and std)
        plot (bool): whether to plot the result
        
    Returns:
        z (float): the calculated Z-score
        p_left (float): P(Z_standard ≤ z)
        p_right (float): P(Z_standard ≥ z)
    
    arr = np.asarray(data)
    mu = np.mean(arr)
    sigma = np.std(arr, ddof=0)  # population std by default
    z = (x - mu) / sigma
    
    # Standard normal cumulative probabilities
    p_left = norm.cdf(z)
    p_right = 1 - p_left
    
    if plot:
        xs = np.linspace(-4, 4, 1000)
        ys = norm.pdf(xs)
        plt.figure(figsize=(8, 5))
        plt.plot(xs, ys, label='Standard Normal PDF')
        # shade area below z
        mask = xs <= z
        plt.fill_between(xs, ys, where=mask, color='skyblue', alpha=0.5,
                         label=f"P(Z ≤ {z:.2f}) = {p_left:.3f}")
        plt.axvline(z, color='red', linestyle='--')
        plt.title(f"Standard Normal Distribution with Z = {z:.2f}")
        plt.xlabel("Z-value")
        plt.ylabel("Density")
        plt.legend()
        plt.grid(True)
        plt.show()
    
    return z, p_left, p_right






Q.15  Implement hypothesis testing using Z-statistics for a sample dataset
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def z_test(sample, pop_mean, pop_std, alpha=0.05, alternative='two-sided'):
    """
    Perform a one-sample Z-test.

    Parameters:
        sample (array-like): observed data
        pop_mean (float): mean under H0
        pop_std (float): known population standard deviation
        alpha (float): significance level (default 0.05)
        alternative (str): 'two-sided', 'greater', or 'less'

    Returns:
        z_stat (float): Z statistic
        p_value (float): p-value
    """
    sample = np.asarray(sample)
    n = len(sample)
    sample_mean = np.mean(sample)
    se = pop_std / np.sqrt(n)
    z_stat = (sample_mean - pop_mean) / se

    if alternative == 'two-sided':
        p_value = 2 * norm.sf(abs(z_stat))
        crit = norm.ppf(1 - alpha / 2)
    elif alternative == 'greater':
        p_value = norm.sf(z_stat)
        crit = norm.ppf(1 - alpha)
    else:  # 'less'
        p_value = norm.cdf(z_stat)
        crit = norm.ppf(alpha)

    return z_stat, p_value, crit

# Example usage
np.random.seed(0)
sample_data = np.random.normal(loc=102, scale=10, size=40)  # sample
pop_mean = 100
pop_std = 15

z_stat, p_val, crit_value = z_test(sample_data, pop_mean, pop_std, alpha=0.05)
print(f"Z-statistic: {z_stat:.2f}, p-value: {p_val:.3f}, critical value: ±{crit_value:.2f}")





Q16 Create a confidence interval for a dataset using Python and interpret the result
ANS: import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def mean_confidence_interval(data, confidence=0.95):
    """
    Compute the confidence interval for the sample mean using t-distribution.
    Returns (mean, lower_bound, upper_bound).
    """
    arr = np.array(data)
    n = len(arr)
    mean = np.mean(arr)
    sem = stats.sem(arr)  # Standard error of the mean
    # Compute the critical t-value
    confidence_interval = stats.t.interval(alpha=confidence, df=n-1, loc=mean, scale=sem)
    return mean, confidence_interval[0], confidence_interval[1]

def plot_confidence_interval(data, confidence=0.95):
    mean, lower, upper = mean_confidence_interval(data, confidence)
    plt.figure(figsize=(8, 4))
    plt.errorbar(0, mean, yerr=[[mean - lower], [upper - mean]], fmt='o', capsize=10, color='blue')
    plt.xlim(-1, 1)
    plt.xticks([])
    plt.ylabel('Value')
    plt.title(f'{int(confidence*100)}% Confidence Interval for the Mean')
    plt.text(0, lower, f'{lower:.2f}', va='top', ha='center')
    plt.text(0, upper, f'{upper:.2f}', va='bottom', ha='center')
    plt.show()
    return mean, lower, upper

# Example data
data = [12, 15, 14, 10, 13, 17, 14, 15, 16, 14]
mean, lower, upper = plot_confidence_interval(data, confidence=0.95)
print(f"Sample Mean = {mean:.2f}")
print(f"95% Confidence Interval = ({lower:.2f}, {upper:.2f})")






Q.17 Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean
ANS:  import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# 1. Generate random data from a normal distribution
np.random.seed(0)  # For reproducibility
data = np.random.normal(loc=50, scale=5, size=100)  # mean=50, std=5, n=100

# 2. Compute sample statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # unbiased estimator
n = len(data)

# 3. Calculate the critical z-value for 95% CI
confidence = 0.95
z_crit = stats.norm.ppf((1 + confidence) / 2)

# 4. Compute the margin of error
stderr = sample_std / np.sqrt(n)
margin = z_crit * stderr

# 5. Determine the confidence interval
ci_lower = sample_mean - margin
ci_upper = sample_mean + margin

# Display results
print(f"Sample mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")






Q.18 Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define parameters for the normal distribution
mu = 5       # mean
sigma = 2    # standard deviation

# Generate a range of x-values around the mean (±3σ)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 500)

# Compute the PDF values at each x
pdf_vals = norm.pdf(x, loc=mu, scale=sigma)

# Plot the PDF curve
plt.figure(figsize=(8, 5))
plt.plot(x, pdf_vals, label=f'N({mu}, {sigma}²)')
plt.fill_between(x, pdf_vals, alpha=0.2)
plt.title('Normal Distribution PDF')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()






Q.19  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution
ANS: import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_val = 7           # Average event rate (λ)
k = np.arange(0, 17)     # Values from 0 to 16

# Compute Poisson CDF values
cdf_vals = poisson.cdf(k, mu=lambda_val)

# Display cumulative probabilities
for val, prob in zip(k, cdf_vals):
    print(f"P(X ≤ {val}) = {prob:.3f}")

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(k, cdf_vals, where='post', marker='o', color='purple')
plt.title(f'Poisson Distribution CDF (λ = {lambda_val})')
plt.xlabel('k')
plt.ylabel('Cumulative Probability P(X ≤ k)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()






Q.20  Simulate a random variable using a continuous uniform distribution and calculate its expected value
ANS: import numpy as np

# Define interval
a, b = 2.0, 5.0

# Simulate random variables from Uniform(a, b)
np.random.seed(42)
samples = np.random.uniform(low=a, high=b, size=1000000)

# Empirical mean (simulation result)
empirical_mean = np.mean(samples)

# Theoretical mean
theoretical_mean = (a + b) / 2

print(f"Empirical Mean (simulation): {empirical_mean:.4f}")
print(f"Theoretical Expected Value:   {theoretical_mean:.4f}")







Q.21 Write a Python program to compare the standard deviations of two datasets and visualize the difference
ANS:  import numpy as np
import matplotlib.pyplot as plt

# Sample datasets
data_A = np.random.normal(loc=50, scale=5, size=1000)
data_B = np.random.normal(loc=50, scale=10, size=1000)

# Calculate standard deviations
std_A = np.std(data_A)
std_B = np.std(data_B)

# Print standard deviations
print(f"Standard Deviation of Data A: {std_A:.2f}")
print(f"Standard Deviation of Data B: {std_B:.2f}")

# Create histograms
plt.figure(figsize=(12, 6))

# Plot for Data A
plt.subplot(1, 2, 1)
plt.hist(data_A, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(np.mean(data_A), color='red', linestyle='dashed', linewidth=1)
plt.axvline(np.mean(data_A) + std_A, color='green', linestyle='dashed', linewidth=1)
plt.axvline(np.mean(data_A) - std_A, color='green', linestyle='dashed', linewidth=1)
plt.title(f"Data A: Mean & ±1 Std Dev")
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot for Data B
plt.subplot(1, 2, 2)
plt.hist(data_B, bins=30, color='lightgreen', edgecolor='black', alpha=0.7)
plt.axvline(np.mean(data_B), color='red', linestyle='dashed', linewidth=1)
plt.axvline(np.mean(data_B) + std_B, color='green', linestyle='dashed', linewidth=1)
plt.axvline(np.mean(data_B) - std_B, color='green', linestyle='dashed', linewidth=1)
plt.title(f"Data B: Mean & ±1 Std Dev")
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()







Q.22 Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution
ANS: import numpy as np

# Generate a dataset from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# Calculate Range
data_range = np.ptp(data)

# Calculate Interquartile Range (IQR)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

print(f"Range: {data_range}")
print(f"Interquartile Range (IQR): {iqr}")





Q.23 Implement Z-score normalization on a dataset and visualize its transformation
ANS: import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate a dataset from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# Calculate mean and standard deviation
mean = np.mean(data)
std_dev = np.std(data)

# Perform Z-score normalization
z_scores = (data - mean) / std_dev

# Plotting the original and normalized data
plt.figure(figsize=(12, 6))

# Original data histogram
plt.subplot(1, 2, 1)
sns.histplot(data, kde=True, color='blue', bins=30)
plt.title("Original Data")
plt.xlabel("Value")
plt.ylabel("Frequency")

# Normalized data histogram
plt.subplot(1, 2, 2)
sns.histplot(z_scores, kde=True, color='green', bins=30)
plt.title("Z-Score Normalized Data")
plt.xlabel("Z-Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()






Q.24  Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal
distribution.
ANS:import numpy as np
from scipy.stats import skew, kurtosis

def calculate_skewness_kurtosis(data):
    """
    Calculate the skewness and kurtosis of a dataset.

    Parameters:
    - data (array-like): The dataset to analyze.

    Returns:
    - tuple: Skewness and kurtosis values.
    """
    skewness_value = skew(data)
    kurtosis_value = kurtosis(data, fisher=True)  # Fisher's definition subtracts 3
    return skewness_value, kurtosis_value

# Generate a dataset from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# Calculate skewness and kurtosis
skewness_value, kurtosis_value = calculate_skewness_kurtosis(data)

print(f"Skewness: {skewness_value:.4f}")
print(f"Kurtosis: {kurtosis_value:.4f}")
